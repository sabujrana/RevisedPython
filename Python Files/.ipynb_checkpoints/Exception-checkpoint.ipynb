# %% [markdown]
# ## Exception

# %%
"""
-> mistakes while writing a program leads to error when we try to run it.
-> python terminates as soon as it encounters an unhandled error; these error classified as:
(1) Syntax Error
(2) Logical Error(Exception)
"""
# Out:
# '\n-> mistakes while writing a program leads to error when we try to run it.\n-> python terminates as soon as it encounters an unhandled error; these error classified as:\n(1) Syntax Error\n(2) Logical Error(Exception)\n'

# %% [markdown]
# ### Syntax Error

# %%
"""
-> caused by not following proper structure(syntax) of language is syntax or parsing error
"""
if a < 3

"""
-> arrow indicates where the parser ran into syntax error
-> colon is missing in that if statment
"""
# Out:
#   File "<ipython-input-10-9991ee258631>", line 4
#     if a < 3
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Logical Error

# %%
"""
-> errors that occurs at runtime(after passing syntax test) are called exception or logical errors
-> they occur when we try to open file(or reading) that does not exist(FileNotFoundError), divide by zero
(ZeroDivisionError), or try to import module that does not exist(ImportError)
-> whenever these runtime error occurs python creates exception object
-> If not handled properly it prints a traceback to that error along with some details about that error
"""
#1/0 #raises ZeroDivisionError

#open('hello.txt') #raises FileNotFoundError
# Out:
# '\n-> errors that occurs at runtime(after passing syntax test) are called exception or logical errors\n-> they occur when we try to open file(or reading) that does not exist(FileNotFoundError), divide by zero\n(ZeroDivisionError), or try to import module that does not exist(ImportError)\n-> whenever these runtime error occurs python creates exception object\n-> If not handled properly it prints a traceback to that error along with some details about that error\n'

# %% [markdown]
# ### Built-in Exception

# %%
"""
-> illegal operation raise exceptions
-> there are plenty of built-in exception which is raised when corresponding errors occurs.
-> can view built-in exceptions using built-in local() function
"""
print(dir(locals()['__builtins__']))


"""
-> locals()['__builtins__'] returns module of built-in exception, function and attributes 
-> dir allows us to list these attributes as string

Common built-in exception:

AssertionError: raised when 'assert' statement fails
AttributeError: raised when attribute assignment or reference fails
EOFError: raised when input() function hits end-of-file condition
FloatingPointError(): raised when a floating point operation fails
GeneratorExit: raised when generator's close() method is called
ImportError: raised when the imported module is not found
IndexError: raised when the index of sqeuence is out of range
KeyError: raised when key is not found in dictionary
KeyboardInterrupt: raised when user hits the interrupt key(ctr+c or Delete)
MemoryError: raised when an operation runs out of memory
NameError: raised when variable is not found in local or global scope
NotImplementedError: raised by abstract methods
OSError: raised when system operation causes systme related error
OverFlowError: raised when result of an arithematic operation is too large to be represented
ReferenceError: raised when a weak reference proxy is used to access a garbage collected referent
RuntimeError: raised when an error does not fall under any other category 
StopIteration: raised by next() function to indicate that there is no further item to be returned by iterator.
SyntaxError: raised by parser when syntax error is encountered
IndentationError: raised when there is incorrect indentation
TabError: raised when indentation consists of inconsistent tabs and spaces
SystemError: raised when interpreter detects internal error
SystmeExit: raised by sys.exit() function
TypeError: raised when a function or operation is applied to an object of incorrect type
UnboundLocalError: raised when a reference is made to a local variable in function or method, but not value has
been bound to that variable
UnicodeError: raised when Unicode-related encoding or decoding error occurs
UnicodeEncodeError: raised when a Unicode-related error occurs during encoding 
UnicodeDecodeError: raised wnen a Unicode-related error occurs during decoding
UnicodeTranslateError: raised when Unicode-related error occurs during translating
ValueError: raised when function gets an argument of correct type but improper value
ZeroDivisionError: raised when second operand of division or modulo operation is zero

"""
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...
